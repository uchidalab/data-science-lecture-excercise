# %%
####################################
# 練習1
#以下の3人のBMIを計算し、BMIsという名前のリストに下記の順で入れてみよう
#A君：1.7m, 52kg
#B君：1.6m, 75kg
#C君：1.8m, 73kg
#リストBMIsの1番目（B君）の値を呼び出してみよう

# [[名前、体重、身長], […], […]]
info = [["A", 52, 1.7], ["B", 75, 1.6],["C", 73, 1.8]]

BMIs=[]
#A君：1.7m, 52kg
#BMI=info[0][1]/(info[0][2]*info[0][2])
id = 0
weight = info[id][1]
height = info[id][2]
BMI = weight/(height*height)
BMIs.append(BMI) # append はlistの最後に要素を追加する関数
    
#B君：1.6m, 75kg
id = 1
weight = info[id][1]
height = info[id][2]
BMI = weight/(height*height)
BMIs.append(BMI)

#C君：1.8m, 73kg
id = 2
weight = info[id][1]
height = info[id][2]
BMI = weight/(height*height)
BMIs.append(BMI)

print(BMIs)

#リストBMIsの1番目（B君）の値を呼び出してみよう
print( BMIs[1] )
# Out:
# [17.99307958477509, 29.296874999999993, 22.530864197530864]
# 29.296874999999993

# %%
# 練習2
#BMIを入力として与えて、以下のように表示するプログラムを作ろう！
#18.5未満の場合、「やせ型」と表示
#18.5以上25未満の場合、「標準」と表示
#25以上の場合、「肥満気味」と表示
#
#以下の3人のBMIを計算し、上のプログラムで動かそう
#A君：1.7m, 52kg
weight=52
height=1.7
BMI=weight/(height*height)
if BMI<18.5: # 18.5未満か？
    print( "やせ型" )
elif BMI>=18.5 and BMI<25: # 18.5以上25未満か？
    print( "標準" )
elif BMI>=25: # 25以上か？
    print( "肥満気味" )

#B君：1.6m, 75kg
weight=75
height=1.6
BMI=weight/(height*height)
if BMI<18.5: # 18.5未満か？
    print( "やせ型" )
elif BMI>=18.5 and BMI<25: # 18.5以上25未満か？
    print( "標準" )
elif BMI>=25: # 25以上か？
    print( "肥満気味" )
    
#C君：1.8m, 73kg
weight=73
height=1.8
BMI=weight/(height*height)
if BMI<18.5: # 18.5未満か？
    print( "やせ型" )
elif BMI>=18.5 and BMI<25: # 18.5以上25未満か？
    print( "標準" )
elif BMI>=25: # 25以上か？
    print( "肥満気味" )
# Out:
# やせ型
# 肥満気味
# 標準

# %%
# 練習3
# 練習２で計算したA君、B君、C君のBMIのリストをfor文を使って、
# 順に呼び出してprint文で表示してみよう

# 方法1
for i in range(3):
    print( BMIs[i] )

print("\n") # 改行

# 方法2
for bmi in BMIs:
  print(bmi)
# Out:
# 17.99307958477509
# 29.296874999999993
# 22.530864197530864
#
#
# 17.99307958477509
# 29.296874999999993
# 22.530864197530864

# %%
# 練習4
# “height_weight_small.csv”ファイルを読み込んで、
# 身長データを各行に順番に表示してみよう

#from google.colab import files
#files.upload()

import pandas as pd
# csvファイルを読み込む
data = pd.read_csv("./data/height_weight_small.csv")
print(data.shape) # shape は表の(行数,列数)

# 各行ごとに身長を表示
for i in range(data.shape[0]): # shape[0]は表の行数
    #print("Height:{}".format(data.iloc[i].Ht))
    print("Height:{}".format(data.Ht[i])) # Htは表の"Ht"(身長)列の全要素を表し、Ht[i]はi行目の"Ht"列の要素を表す。
# Out:
# (10, 4)
# Height:195.9
# Height:189.7
# Height:177.8
# Height:185.0
# Height:184.6
# Height:174.0
# Height:186.2
# Height:173.8
# Height:171.4
# Height:179.9

# %%
# 練習5
#当選確率が1/5のくじ引きを作ろう
import random
for i in range(5): # くじを5回までひけます
    number = random.randint(1, 5) # 1から10までの数字を1つもらえます
    if number == 1: # もし1が出たら・・・
        print( "atari !" )  # あたりです！
        break # 当たったので終わります
    else:
        print( "hazure" ) # はずれなのでもう一回引きましょう
# Out:
# hazure
# atari !

# %%
# 練習6
#入力xを10倍する関数tentimesを定義しよう
def tentimes(x):
    a = x*10
    return a

# %%
# 練習6（続き）
#tentimesを呼び出して、入力に5を与えて計算しよう
x = 5
y = tentimes(x)
print( y )
# Out:
# 50
